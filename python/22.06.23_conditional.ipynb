# %% [markdown]
# ### 조건문
# - 상황에 따라 실행 흐름을 다르게 하는 문법
#
#     - 조건문 키워드 : if, elif , else
# - 조건문 if
# ![image.png](attachment:image.png)

# %%
if True:
    print("실행문장 실행")
# Out:
# 실행문장 실행

# %%
if False:
    print("실행문장 실행")

# %%
if True:
    print("실행문장 실행")
print("if문 밖에 있는 실행문장")
# Out:
# 실행문장 실행
# if문 밖에 있는 실행문장

# %%
if False:
    print("실행문장 실행")
print("if문 밖에 있는 실행문장")
# Out:
# if문 밖에 있는 실행문장

# %%
money = 9000
if money >= 10000:
    print("택시를 탄다")

# %% [markdown]
# #### if else
# ![image.png](attachment:image.png)

# %%
if True:
    print("실행문장1")
else:
    print("실행문장2")
# Out:
# 실행문장1

# %%
if False:
    print("실행문장1")
else:
    print("실행문장2")
# Out:
# 실행문장2

# %%
money = 9000
if money >= 10000:
    print("택시를 탄다.")
else:
    print("버스를 탄다.")
# Out:
# 버스를 탄다.

# %%
num = int(input("정수 입력 >> "))
if num % 3 == 0 & num % 5==0:
    print("3과 5의 배수입니다.")
else:
    print("3과 5의 배수가 아닙니다.")
# Out:
# 정수 입력 >> 45
# 3과 5의 배수입니다.

# %%
num = input("주민등록번호 뒷자리 입력 >>")

if num[0] == "1" or num[0] == "3":
    print("당신은 남자입니다.^^7")
else:
    print("당신은 여자입니다.^^*")
# Out:
# 주민등록번호 뒷자리 입력 >>2832560
# 당신은 여자입니다.^^*

# %%
num2 = int(input("주민등록번호 뒷자리 입력 >> "))

if num2 // 1000000 == 1 or num2 // 1000000 == 3:
    print("당신은 남자입니다.^^7")
else:
    print("당신은 여자입니다.^^*")
# Out:
# 주민등록번호 뒷자리 입력 >> 2832560
# 당신은 여자입니다.^^*

# %%
name = input("이름 입력 >> ")
age = int(input("나이 입력 >> "))
card = input("카드 소지 여부(소지, 미소지) >> ")
money = 35000

if age >= 19:
    if card == "소지":
        print(f"{name}은 입장료 {int(money-(money*0.3))}원에 예약되셨습니다.")
    else:
        print(f"{name}은 입장료 {(money)}원에 예약되셨습니다.")
else:
    if card == "소지":
        print(f"{name}은 입장료 {int(money-(money*0.5)-(money*0.5)*0.1)}원에 예약되셨습니다.")
    else:
        print(f"{name}은 입장료 {int(money-(money*0.5))}원에 예약되셨습니다.")
# Out:
# 이름 입력 >> 성우
# 나이 입력 >> 18
# 카드 소지 여부(소지, 미소지) >> 소지
# 성우은 입장료 15750원에 예약되셨습니다.

# %%
name = input("이름 입력 >> ")
age = int(input("나이 입력 >> "))
card = input("카드 소지 여부(소지, 미소지) >> ")
fee = 35000

# 미성년일 경우
if age < 19:
    fee *= 0.5
    if card == "소지":
        fee *= 0.9
else:
    fee = fee
    if card == "소지":
        fee *= 0.7

print(f"{name}님은 입장료 {int(fee)}원에 예약되셨습니다.")
# Out:
# 이름 입력 >> 성우
# 나이 입력 >> 18
# 카드 소지 여부(소지, 미소지) >> 소지
# 성우님은 입장료 15750원에 예약되셨습니다.

# %%
count0fMask = int(input("마스크 개수 입력 >> "))

if count0fMask//8 > 0:
    print("8개들이 포장지 개수 :", count0fMask//8)
    if (count0fMask%8)%5 > 0:
        print("5개들이 포장지 개수 :", ((count0fMask%8)//5) + 1)
    else:
        print("5개들이 포장지 개수 :", (count0fMask%8)//5)
else:
    print("8개들이 포장지 개수 :", count0fMask//8)
    if (count0fMask%8)%5 > 0:
        print("5개들이 포장지 개수 :", ((count0fMask%8)//5) + 1)
    else:
        print("5개들이 포장지 개수 :", (count0fMask%8)//5)
# Out:
# 마스크 개수 입력 >> 6
# 8개들이 포장지 개수 : 0
# 5개들이 포장지 개수 : 2

# %%
count0fMask = int(input("마스크 개수 입력 >> "))

eightBox = count0fMask // 8
if ((count0fMask%8)%5) > 0:
    fiveBox = ((count0fMask%8) // 5) + 1
else:
    fiveBox = (count0fMask%8) // 5
    
print(f"8개들이 포장지 개수 : {eightBox}")
print(f"8개들이 포장지 개수 : {fiveBox}")
# Out:
# 마스크 개수 입력 >> 5
# 8개들이 포장지 개수 : 0
# 8개들이 포장지 개수 : 1

# %% [markdown]
# ### 조건문 elif

# %%
num1 = int(input("첫 번째 정수 입력 >>"))
num2 = int(input("두 번째 정수 입력 >>"))

if num1 > num2:
    print("첫 번째 정수가 더 큽니다.")
elif num1 < num2:
    print("두 번째 정수가 더 큽니다.")
else:
    print("두 수가 똑같습니다.")
# Out:
# 첫 번째 정수 입력 >>5
# 두 번째 정수 입력 >>5
# 두 수가 똑같습니다.

# %%
score = int(input("점수 입력 >>"))

if score >= 90:
    print(f"{score}점수은 A학점 입니다.")
elif score >= 80:
    print(f"{score}점수은 B학점 입니다.")
elif score >= 70:
    print(f"{score}점수은 C학점 입니다.")
elif score >= 60:
    print(f"{score}점수은 D학점 입니다.")
else:
    print(f"{score}점수은 F학점 입니다.")
# Out:
# 점수 입력 >>70
# 70점수은 C학점 입니다.

# %%
x = int(input("x값을 입력하세요 : "))
y = int(input("y값을 입력하세요 : "))

if x > 0 and y > 0 :
    print(f"좌표({x},{y})는 1사분면 입니다.")
elif x < 0 and y > 0:
    print(f"좌표({x},{y})는 2사분면 입니다.")
elif x < 0 and y < 0:
    print(f"좌표({x},{y})는 3사분면 입니다.")      
elif x > 0 and y < 0:
    print(f"좌표({x},{y})는 4사분면 입니다.")
else:
    print(f"좌표({x},{y})는 가운데 입니다.")
# Out:
# x값을 입력하세요 : 0
# y값을 입력하세요 : 0
# 좌표(0,0)는 가운데 입니다.

# %%
fee = 1500
age = int(input("나이 입력 >> "))

if age < 5:
    print(f"요금은 {int(fee*0.5)}원 입니다.")
elif age >= 65:
    print(f"요금은 {int(fee*0.25)}원 입니다.")
elif age < 20:
    print(f"요금은 {int(fee*0.75)}원 입니다.")
else:
    print(f"요금은 {fee}원 입니다.")
# Out:
# 나이 입력 >> 19
# 요금은 1125원 입니다.

# %%
print('='*47)
print('='*16+"-"*4+" 자판기 "+"-"*4+'='*15)
print('='*47)
print("="*2 + " 1.콜라 "+"="*2+" 2.사이다 "+"="*2+" 3.물 "+"="*8+"insert"+"="*3)
print("="*2+"-"*8+"="*2+"-"*10+"="*2+"-"*6+"="*8+"-"*6+"="*3)
print("="*2 + "   600  "+"="*2+"    800   "+"="*2+" 1000 "+"="*8+" 000원"+"="*3)
print('='*38+'-'*6+'='*3)
print('='*47)
print('='*2+'+'*43+'='*2)
print('='*2+'+'*43+'='*2)
print('='*2+'+'*43+'='*2)
print('='*2+'+'*14+"               "+'+'*14+'='*2)
print('='*2+'+'*14+"     SMHRD     "+'+'*14+'='*2)
print('='*2+'+'*14+"               "+'+'*14+'='*2)
print('='*2+'+'*43+'='*2)
print('='*2+'+'*43+'='*2)
print('='*47)
print('='*47)
print("  "+'='*3+"                                     "+'='*3+"  ")
print("  "+'='*3+"                                     "+'='*3+"  ")
coin = int(input("insert coin >>"))
menu = int(input("메뉴 선택 >>"))

if coin < 600:
    print("잔액 부족")
else:
    if menu == 1:
        balance = (coin-600)
        a =  balance // 1000
        b = (balance % 1000) // 500
        c = ((balance % 1000) % 500) // 100
        print(f"잔돈 >> 1000원 {a}개, 500원 {b}개, 100원 {c}개")
    elif menu == 2:
        balance = (coin-800)
        a =  balance // 1000
        b = (balance % 1000) // 500
        c = ((balance % 1000) % 500) // 100
        print(f"잔돈 >> 1000원 {a}개, 500원 {b}개, 100원 {c}개")
    elif menu == 3:
        balance = (coin-1000)
        a =  balance // 1000
        b = (balance % 1000) // 500
        c = ((balance % 1000) % 500) // 100
        print(f"잔돈 >> 1000원 {a}개, 500원 {b}개, 100원 {c}개")
    else:
        print("잘못된 메뉴 출력")
# Out:
# ...
# ================---- 자판기 ----===============
# ...
# == 1.콜라 == 2.사이다 == 3.물 ========insert===
# ==--------==----------==------========------===
# ==   600  ==    800   == 1000 ======== 000원===
# ======================================------===
# ...
# ==+++++++++++++++++++++++++++++++++++++++++++==
# ==+++++++++++++++++++++++++++++++++++++++++++==
# ==+++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++               ++++++++++++++==
# ==++++++++++++++     SMHRD     ++++++++++++++==
# ==++++++++++++++               ++++++++++++++==
# ==+++++++++++++++++++++++++++++++++++++++++++==
# ==+++++++++++++++++++++++++++++++++++++++++++==
# ...
#   ===                                     ===
#   ===                                     ===
# insert coin >>5000
# 메뉴 선택 >>3
# 잔돈 >> 1000원 4개, 500원 0개, 100원 0개

# %%
# 조건문을 활용한 자판기 만들기!1
money = int(input("insert coin >> "))
num = int(input("메뉴 선택 >> "))

# 메뉴 선택하기
if money >= 600 :
    # 1번 메뉴 선택
    if num == 1:
        money -= 600
    elif num == 2:
        money -= 800
    elif num == 3:
        money -= 1000
    else:
        print("잘못된 메뉴입니다.")
    # 잔돈 계산
    cash_1000, cash_500, cash_100 = 0,0,0
    
    if money >= 1000:
        # 천원짜리 개수
        cash_1000 = money // 1000
        # 오백원짜리 개수
        cash_500 = (money%1000) // 500
        # 백원짜리 개수
        cash_100 = ((money%1000)%500) // 100
    # 천원 미만 오백원 이상일 경우
    elif money >= 500:
        cash_500 = money // 500
        cash_100 = (money%500) // 100
    # 오백원 미만일 경우
    else :
        cash_100 = money // 100
    
    print(f"잔돈 >> 천원 {cash_1000}개, 오백원 {cash_500}개, 백원 {cash_100}개")
    
else:
    print("돈을 더 넣어주세요~~!")
# Out:
# insert coin >> 5600
# 메뉴 선택 >> 3
# 잔돈 >> 천원 4개, 오백원 1개, 백원 1개
